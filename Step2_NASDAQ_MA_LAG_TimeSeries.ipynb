# %% [markdown]
# Student Name:  Sue Mir
#
# Cohort: Data Science / 17/12/2020 - Module 5 - Capstone

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Project-Description-and-Module-Analysis" data-toc-modified-id="Project-Description-and-Module-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Project Description and Module Analysis</a></span></li><li><span><a href="#Obtain" data-toc-modified-id="Obtain-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Obtain</a></span><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Define-Functions" data-toc-modified-id="Define-Functions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Define Functions</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Load Data</a></span><ul class="toc-item"><li><span><a href="#Check-Null-Values" data-toc-modified-id="Check-Null-Values-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Check Null Values</a></span></li><li><span><a href="#Examine-Data-Types" data-toc-modified-id="Examine-Data-Types-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Examine Data Types</a></span></li></ul></li></ul></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Melt-TS-Data" data-toc-modified-id="Melt-TS-Data-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Melt TS Data</a></span></li><li><span><a href="#Visualise-Data" data-toc-modified-id="Visualise-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualise Data</a></span></li></ul></li><li><span><a href="#Model-Daily-ma-1-10" data-toc-modified-id="Model-Daily-ma-1-10-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model Daily ma 1-10</a></span><ul class="toc-item"><li><span><a href="#Rolling-Statistics" data-toc-modified-id="Rolling-Statistics-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Rolling Statistics</a></span><ul class="toc-item"><li><span><a href="#Validate-Stationarity" data-toc-modified-id="Validate-Stationarity-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Validate Stationarity</a></span></li><li><span><a href="#Remove-Trends" data-toc-modified-id="Remove-Trends-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Remove Trends</a></span><ul class="toc-item"><li><span><a href="#Difference" data-toc-modified-id="Difference-4.1.2.1"><span class="toc-item-num">4.1.2.1&nbsp;&nbsp;</span>Difference</a></span></li><li><span><a href="#Subtract-Weighted-Rolling-Mean" data-toc-modified-id="Subtract-Weighted-Rolling-Mean-4.1.2.2"><span class="toc-item-num">4.1.2.2&nbsp;&nbsp;</span>Subtract Weighted Rolling Mean</a></span></li><li><span><a href="#Validate-Stationarity" data-toc-modified-id="Validate-Stationarity-4.1.2.3"><span class="toc-item-num">4.1.2.3&nbsp;&nbsp;</span>Validate Stationarity</a></span></li><li><span><a href="#Seasonal-Decomposition" data-toc-modified-id="Seasonal-Decomposition-4.1.2.4"><span class="toc-item-num">4.1.2.4&nbsp;&nbsp;</span>Seasonal Decomposition</a></span></li><li><span><a href="#ACF/PACF" data-toc-modified-id="ACF/PACF-4.1.2.5"><span class="toc-item-num">4.1.2.5&nbsp;&nbsp;</span>ACF/PACF</a></span></li><li><span><a href="#PDQ/S-Parameters" data-toc-modified-id="PDQ/S-Parameters-4.1.2.6"><span class="toc-item-num">4.1.2.6&nbsp;&nbsp;</span>PDQ/S Parameters</a></span></li><li><span><a href="#ARMA-Model" data-toc-modified-id="ARMA-Model-4.1.2.7"><span class="toc-item-num">4.1.2.7&nbsp;&nbsp;</span>ARMA Model</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-4.1.2.8"><span class="toc-item-num">4.1.2.8&nbsp;&nbsp;</span>Train Test Split</a></span><ul class="toc-item"><li><span><a href="#BEFORE-Covid19" data-toc-modified-id="BEFORE-Covid19-4.1.2.8.1"><span class="toc-item-num">4.1.2.8.1&nbsp;&nbsp;</span>BEFORE Covid19</a></span></li><li><span><a href="#FIRST-MONTH-Covid19" data-toc-modified-id="FIRST-MONTH-Covid19-4.1.2.8.2"><span class="toc-item-num">4.1.2.8.2&nbsp;&nbsp;</span>FIRST MONTH Covid19</a></span></li><li><span><a href="#DURING-Covid19" data-toc-modified-id="DURING-Covid19-4.1.2.8.3"><span class="toc-item-num">4.1.2.8.3&nbsp;&nbsp;</span>DURING Covid19</a></span></li><li><span><a href="#BEFORE-AND-DURING-Covid19" data-toc-modified-id="BEFORE-AND-DURING-Covid19-4.1.2.8.4"><span class="toc-item-num">4.1.2.8.4&nbsp;&nbsp;</span>BEFORE AND DURING Covid19</a></span></li><li><span><a href="#Analysis-of-Results" data-toc-modified-id="Analysis-of-Results-4.1.2.8.5"><span class="toc-item-num">4.1.2.8.5&nbsp;&nbsp;</span>Analysis of Results</a></span><ul class="toc-item"><li><span><a href="#FIRST-MONTH-of-Covid19" data-toc-modified-id="FIRST-MONTH-of-Covid19-4.1.2.8.5.1"><span class="toc-item-num">4.1.2.8.5.1&nbsp;&nbsp;</span>FIRST MONTH of Covid19</a></span></li><li><span><a href="#DURING-Covid19" data-toc-modified-id="DURING-Covid19-4.1.2.8.5.2"><span class="toc-item-num">4.1.2.8.5.2&nbsp;&nbsp;</span>DURING Covid19</a></span></li><li><span><a href="#BEFORE-AND-DURING-Covid19" data-toc-modified-id="BEFORE-AND-DURING-Covid19-4.1.2.8.5.3"><span class="toc-item-num">4.1.2.8.5.3&nbsp;&nbsp;</span>BEFORE AND DURING Covid19</a></span></li></ul></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#Final-Analysis" data-toc-modified-id="Final-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Final Analysis</a></span></li><li><span><a href="#Recommendations" data-toc-modified-id="Recommendations-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Recommendations</a></span></li></ul></div>

# %% [markdown]
# ********************************

# %% [markdown]
# # Project Description and Module Analysis
#
# > This module is part of the project 'Were US Covid19 daily case numbers a predictor for the NASDAQ100 stock market index in 2020'?
#
# >The Main Goal of this module is to analyse the following:
#
# >> Were the US Covid19 daily (and moving average ma) case numbers a strong predictor for the movement in the target NASDAQ100 daily stock close price (and moving averages) in the 6 months before the crash as compared to during or after?

# %% [markdown]
# # Obtain

# %% [markdown]
# ## Import Libraries

# %%
# Import necessary libraries
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

plt.style.use('seaborn-notebook')
pd.set_option('display.max_columns', 0)

#For the initial data exploration
import numpy as np
import pandas as pd
import datetime
from datetime import timedelta

#For data visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.lines import Line2D
import matplotlib.font_manager
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
from matplotlib.pylab import rcParams
from matplotlib import pyplot
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from pandas import DataFrame

#For maths
from sklearn.metrics import mean_squared_error
from math import sqrt

#For time series modelling
import itertools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARMA
from sklearn.metrics import mean_squared_error
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf


#Suppress warnings from showing
import warnings
warnings.filterwarnings('ignore')

#Allow ourselves to save models
import pickle

# %% [markdown]
# ## Define Functions

# %%
#Helper Functions
#Source: Flatiron School

def acf_pacf(df,alags=48,plags=48):
    ''' 
        Performs acf/pacf results plot      
                             
        df          Dataframe to Analyse     
    '''

    #Create figure
    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(13,8))
    #Make ACF plot
    plot_acf(df,lags=alags, zero=False,ax=ax1)
    #Make PACF plot
    plot_pacf(df,lags=plags, ax=ax2)
    plt.show()

def seasonal_plots(df,N=13,lags=[12,24,36,48,60,72]):
    ''' 
         Differencing the rolling mean to find seasonality in the resulting acf plot    
                        
         df          Dataframe to Analyse     
    '''

    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(13,8))
    rolling = df - df.rolling(N).mean()
    plot_acf(rolling.dropna(),lags=lags,ax=ax1)
    plot_pacf(rolling.dropna(),lags=lags,ax=ax2)
    plt.show();
    
def train_test(df):
    ''' 
        Sets train and test data for period of prediction     
                         
        df          Dataframe to create split   
    '''

    #Set training data before Covid19 
    train = df[:'2020-04']
    #Set test data starting Covid19
    test = df['2020-05':]
    
    #Set training data first month Covid19 announced
    train_first_month_covid19 = df['2020-02':'2020-03']
    #Set test data
    test_first_month_covid19 = df['2020-04':'2020-05']

    #Set training data before Covid19 
    train_before_covid19 = df['2019-07':'2019-11']
    #train_before_covid19 = df[:'2019-11']
    #Set test data starting Covid19
    test_before_covid19 = df['2019-12':'2020-02']
    
    #Set training data starting into first 5 months of Covid19
    train_during_covid19 = df['2020-03':'2020-05']
    #Set test data end of Covid19 test period last month
    test_during_covid19 = df['2020-06':]
    
    #Set training data from previous year into first 5 months of Covid19
    train_before_and_during_covid19 = df[:'2020-05']
    #Set test data starting Covid19
    test_before_and_during_covid19 = df['2020-06':]
    
    
    return train, test, train_before_covid19, test_before_covid19, train_during_covid19, test_during_covid19, train_before_and_during_covid19, test_before_and_during_covid19, train_first_month_covid19, test_first_month_covid19


def model_fit(df,train, test, pdq=(1,0,1),pdqs=(0,0,0,1), order=(1,2)):
    ''' 
        Performs ARIMA model given defined pdq/s values and returns results     
        
        df          Dataframe to Analyse   
        
        Returns train/test df on the same df modelled   
    '''
    
    history = [x for x in train]
    predictions = list()
    # walk-forward validation
    for t in range(len(test)):
             model = ARIMA(history, order=(1,0,1))
             results = model.fit()
             output = results.forecast()
#              print(results.summary())
             yhat = output[0]
             predictions.append(yhat)
             obs = test[t]
             history.append(obs)
    print('---------------------RESULTS OUTPUT---------------------')
    print(results.summary())
    print('predicted=%f, expected=%f' % (yhat, obs))
    
    print('---------------------RESIDUALS OUPUT---------------------')
    # evaluate residuals
    # line plot of residuals
    residuals = DataFrame(results.resid)
    residuals.plot()
    pyplot.show()
    # density plot of residuals
    residuals.plot(kind='kde')
    pyplot.show()
    # summary stats of residuals
    print(residuals.describe())
    
    
    # evaluate forecasts
    print('---------------------FORECASTS RMSE OUTPUT---------------------')

    rmse = sqrt(mean_squared_error(test, predictions))
    print('Test RMSE: %.3f' % rmse)
    
    print('---------------------TRAIN TEST SPLIT OUTPUT---------------------')
    plt.style.use('seaborn')
    plt.plot(train)
    plt.plot(test)
    plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
    # Define the date format
    date_form = DateFormatter("%Y-%m-%d")
    ax.xaxis.set_major_formatter(date_form)
    # Ensure a major tick for each 4 weeks
    ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))
    plt.show();
    
    return train, test, results, predictions



def test_model(df,pdq=(1,0,1),pdqs=(0,0,0,1), display=True):
    ''' 
            Predicts for 12 months on test model with SARIMA model  
                      
            df          Dataframe to perform predictions    
    '''

    X = df.values
    train, test = X[:-12],X[-12:]
    history = [x for x in train]
    predictions = []
    for t in range(len(test)):
        model = ARIMA(train,order=pdq,seasonal_order=pdq)
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        history.append(test[t])

    if display:
        plt.figure(figsize=(13,6))
        plt.title('Actual Test Data vs. Predictions')
        plt.plot(history[-12:],label='Actual', color='b')
        plt.plot(predictions,label='Predictions',color='r')
        plt.legend(loc='best')
        plt.show()


        
def train_model(train, results, display = True):
    ''' 
        Returns train versus test predictions pefromed on on SARIMA model    
        Transforms data into datetime object with time as index.                     

        train          Train Dataframe for period defined
        results        Results from SARIMA model
    '''

    train_pred = results.predict(-12)

    if display:
        plt.figure(figsize=(13,6))
        train[-60:].plot(label='Actual',color='b')
        train_pred.plot(label='Predicted',color='r')
        plt.legend(loc='best')
        plt.title('Actual Train Data vs. Predicted Returns')
        plt.show()
        

def AIC_PDQS(df):   
    ''' 
         Runs grid search to return lowest AIC result for permutataions of pdq/s values in range 0,2  
                          
         df          Dataframe to anlyse for best pdq/s permutation    
    '''
    
    # Define the p, d and q parameters to take any value between 0 and 2
    p = d = q = range(0, 2)
    
    #     Auto-Regressive (p) -> Number of autoregressive terms.
    #     Integrated (d) -> Number of nonseasonal differences needed for stationarity.
    #     Moving Average (q) -> Number of lagged forecast errors in the prediction equation.

    # Generate all different combinations of p, q and q triplets
    pdq = list(itertools.product(p, d, q))

    # Generate all different combinations of seasonal p, q and q triplets
    pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]


    # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                mod = sm.tsa.statespace.SARIMAX(df,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

                output = mod.fit()
                ans.append([comb, combs, output.aic])
                print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
            except:
                continue
            
    # Find the parameters with minimal AIC value
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
    print(ans_df.loc[ans_df['aic'].idxmin()])
    return ans_df

def validate_stationarity(df):
    '''           
         Returns D.Fuller stationarity test results    
         
         df          Dataframe to test for stationarity    
    '''

    results = adfuller(df.dropna())
    print(f'ADFuller test p-value for ma: 2')
    print('p-value:',results[1])
    print('p-value:',results)
    if results[1]>0.05:
        print('Fail to reject the null hypothesis. Data is not stationary.\n')
    else:
        print('Reject the null hypothesis. Data is stationary.\n')


def make_datetime_index(df,col_to_make_index = 'Date', drop=False, verbose=True):
    '''           
         Transforms data into datetime object with time as index, defaulted as monthly     
         
         df          Dataframe to transform     
    '''

    df[col_to_make_index] = pd.to_datetime(df[col_to_make_index], errors='coerce')
    df = df.set_index('Date', drop=False)
    if verbose:
        display(df.index)
    return df

# %% [markdown]
# ## Load Data

# %%
ndx_data = pd.read_csv('nasdaq100_upto10_ma.csv')

# %%
ndx_data.head()
# Out:
#          Date         Open         High          Low  ...  ndx_ma10  ndx_ma21  ndx_ma28  ndx_ma14
# 0  2019-10-09  7690.529785  7690.529785  7690.529785  ...       NaN       NaN       NaN       NaN
# 1  2020-02-11  9517.860352  9517.860352  9517.860352  ...       NaN       NaN       NaN       NaN
# 2  2020-02-12  9613.200195  9613.200195  9613.200195  ...       NaN       NaN       NaN       NaN
# 3  2020-02-13  9595.700195  9595.700195  9595.700195  ...       NaN       NaN       NaN       NaN
# 4  2020-02-14  9623.580078  9623.580078  9623.580078  ...       NaN       NaN       NaN       NaN
#
# [5 rows x 20 columns]

# %% [markdown]
# ### Check Null Values

# %%
## Data Clean check - are there any null values?

# %%
nulls = ndx_data.isna().sum()
nulls[nulls >0]
# Out:
# ndx_ma2     1
# ndx_ma3     2
# ndx_ma4     3
# ndx_ma5     4
# ndx_ma6     5
# ndx_ma7     6
# ndx_ma8     7
# ndx_ma9     8
# ndx_ma10    9
# ndx_ma21    9
# ndx_ma28    9
# ndx_ma14    6
# dtype: int64

# %% [markdown]
# ### Examine Data Types

# %%
ndx_data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# ndx_ma1      float64
# ndx_ma2      float64
# ndx_ma3      float64
# ndx_ma4      float64
# ndx_ma5      float64
# ndx_ma6      float64
# ndx_ma7      float64
# ndx_ma8      float64
# ndx_ma9      float64
# ndx_ma10     float64
# ndx_ma21     float64
# ndx_ma28     float64
# ndx_ma14     float64
# dtype: object

# %%
ndx_data.describe()
# Out:
#                Open          High           Low  ...      ndx_ma21      ndx_ma28      ndx_ma14
# count     93.000000     93.000000     93.000000  ...     84.000000     84.000000     87.000000
# mean    8873.406985   8873.406985   8873.406985  ...   8793.776190   8793.776190   8828.833569
# std      879.177349    879.177349    879.177349  ...    809.421556    809.421556    832.299243
# min     6994.290039   6994.290039   6994.290039  ...   7324.158984   7324.158984   7216.151437
# 25%     8238.530273   8238.530273   8238.530273  ...   8150.724780   8150.724780   8215.126395
# 50%     8982.759766   8982.759766   8982.759766  ...   8898.056543   8898.056543   8892.588588
# 75%     9613.200195   9613.200195   9613.200195  ...   9439.196411   9439.196411   9514.029297
# max    10209.799805  10209.799805  10209.799805  ...  10020.757031  10020.757031  10063.954241
#
# [8 rows x 19 columns]

# %% [markdown]
# # Data Preprocessing

# %%
ndx_data.shape
# Out:
# (93, 20)

# %% [markdown]
# ## Melt TS Data

# %%
ndx_data = make_datetime_index(ndx_data)
# Out:
# DatetimeIndex(['2019-10-09', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-18', '2020-02-19', '2020-02-20',
#                '2020-02-21', '2020-02-24', '2020-02-25', '2020-02-26',
#                '2020-02-27', '2020-02-28', '2020-03-02', '2020-03-03',
#                '2020-03-04', '2020-03-05', '2020-03-09', '2020-03-10',
#                '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-16',
#                '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#                '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26',
#                '2020-03-27', '2020-03-30', '2020-03-31', '2020-04-01',
#                '2020-04-02', '2020-04-03', '2020-04-06', '2020-04-07',
#                '2020-04-08', '2020-04-09', '2020-04-13', '2020-04-15',
#                '2020-04-16', '2020-04-17', '2020-04-20', '2020-04-21',
#                '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-27',
# ...

# %%
ndx_data.tail()
# Out:
#                  Date          Open          High  ...      ndx_ma21      ndx_ma28      ndx_ma14
# Date                                               ...
# 2020-06-23 2020-06-23  10209.799805  10209.799805  ...   9941.598926   9941.598926  10009.919922
# 2020-06-24 2020-06-24  10002.700195  10002.700195  ...   9932.438965   9932.438965  10042.178571
# 2020-06-25 2020-06-25  10101.799805  10101.799805  ...   9983.770898   9983.770898  10063.954241
# 2020-06-26 2020-06-26   9849.360352   9849.360352  ...  10002.329980  10002.329980  10044.937081
# 2020-06-29 2020-06-29   9961.160156   9961.160156  ...  10020.757031  10020.757031  10037.674247
#
# [5 rows x 20 columns]

# %%
ndx_data = ndx_data.dropna(how='any',axis=0)

# %%
ndx_data.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# ndx_ma1      0
# ndx_ma2      0
# ndx_ma3      0
# ndx_ma4      0
# ndx_ma5      0
# ndx_ma6      0
# ndx_ma7      0
# ndx_ma8      0
# ndx_ma9      0
# ndx_ma10     0
# ndx_ma21     0
# ndx_ma28     0
# ndx_ma14     0
# dtype: int64

# %%
ndx_data.head()
# Out:
#                  Date         Open         High  ...     ndx_ma21     ndx_ma28     ndx_ma14
# Date                                             ...
# 2020-02-24 2020-02-24  9079.629883  9079.629883  ...  9354.355127  9354.355127  9531.708705
# 2020-02-25 2020-02-25  8834.870117  8834.870117  ...  9468.789160  9468.789160  9423.018694
# 2020-02-26 2020-02-26  8873.759766  8873.759766  ...  9404.379102  9404.379102  9315.901507
# 2020-02-27 2020-02-27  8436.669922  8436.669922  ...  9286.726074  9286.726074  9145.454381
# 2020-02-28 2020-02-28  8461.830078  8461.830078  ...  9173.339062  9173.339062  8965.897182
#
# [5 rows x 20 columns]

# %%
# Set as index
ndx_data.set_index(ndx_data['Date'], inplace=True)

# %% [markdown]
# ## Visualise Data

# %%
plt.style.use('seaborn-poster')

def plot_ts(df2,col='ma5',movingaverages=['Close','Low','ndx_ma2','ndx_ma3','ndx_ma4','ndx_ma4','ndx_ma5','ndx_ma6','ndx_ma7','ndx_ma8','ndx_ma9','ndx_ma10']):    
    fig, ax = plt.subplots()
    
    for ma in movingaverages:
        ts = df2[ma]
        ts.plot(label=ma,ax=ax)
        plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
        # Define the date format
        date_form = DateFormatter("%Y-%m-%d")
        ax.xaxis.set_major_formatter(date_form)
        # Ensure a major tick for each 4 weeks
        ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))

    max_ = ts.idxmax()
    crash = '03-2020'
    min_ = ts.loc[crash:].idxmin()

    ax.axvline(max_,label=f'Max Cases after Covid19 Stock Mkt Crash {max_}',color='green', ls=':')
    ax.axvline(crash,label=f'NASDAQ100 Covid 19 Mkt Crash {crash}',color='red', ls=':')
    ax.axvline(min_,label=f'Min Cases during Covid19 Mkt Crash {min_}',color='black')
    ax.legend(bbox_to_anchor=(1.10, 0.5), loc=6, borderaxespad=0.)
    return fig,ax
            
ma_intervals = ['Close','Low','ndx_ma2','ndx_ma3','ndx_ma4','ndx_ma4','ndx_ma5','ndx_ma6','ndx_ma7','ndx_ma8','ndx_ma9','ndx_ma10']
fig,ax = plot_ts(ndx_data, movingaverages=ma_intervals)

# %%
def explore_normality_qqplots(column):
    """ Display qq plot for column in datafile df
    Arguments:
        column - string - data column to create box plot
    Returns: 
    """
    #----------------------------------------------------------------------------------
    #------------Check the normality assumptions by creating a QQ-plot
    #---------------------------------------------------------------------------------- 
    import scipy.stats as stats
    import matplotlib.pyplot as plt
    # %matplotlib inline
    import statsmodels.api as sm
    import statsmodels.stats.api as sms
    import statsmodels.formula.api as smf
    import scipy.stats as stats
    from statsmodels.formula.api import ols
    from scipy import stats
    f = 'Close~' + column
    model = smf.ols(formula=f, data=ndx_data).fit()
    residuals = model.resid
    fig = sm.graphics.qqplot(residuals, dist=stats.norm, line='45', fit=True)
    fig.show()

# for column in df:
#     explore_normality_qqplots(column)   

# Explore further columns of interest after above normalisation results
# for ma in ma_intervals:
#     explore_normality_qqplots(ma)

# explore_normality_qqplots('ma1')

# %%
explore_normality_qqplots('ndx_ma2')

# %%
explore_normality_qqplots('ndx_ma3')

# %%
explore_normality_qqplots('ndx_ma4')

# %%
explore_normality_qqplots('ndx_ma5')

# %%
ndx_data.head()
# Out:
#                  Date         Open         High  ...     ndx_ma21     ndx_ma28     ndx_ma14
# Date                                             ...
# 2020-02-24 2020-02-24  9079.629883  9079.629883  ...  9354.355127  9354.355127  9531.708705
# 2020-02-25 2020-02-25  8834.870117  8834.870117  ...  9468.789160  9468.789160  9423.018694
# 2020-02-26 2020-02-26  8873.759766  8873.759766  ...  9404.379102  9404.379102  9315.901507
# 2020-02-27 2020-02-27  8436.669922  8436.669922  ...  9286.726074  9286.726074  9145.454381
# 2020-02-28 2020-02-28  8461.830078  8461.830078  ...  9173.339062  9173.339062  8965.897182
#
# [5 rows x 20 columns]

# %% [markdown]
# # Model Daily ma 1-10

# %%
ts_ndx_close_ma = ndx_data['Close']

# %%
ts_ndx_close_ma.head()
# Out:
# Date
# 2020-02-24    9079.629883
# 2020-02-25    8834.870117
# 2020-02-26    8873.759766
# 2020-02-27    8436.669922
# 2020-02-28    8461.830078
# Name: Close, dtype: float64

# %%
ts_ndx_close_ma.isna().sum()
# Out:
# 0

# %%
ts_ndx_close_ma.head()
# Out:
# Date
# 2020-02-24    9079.629883
# 2020-02-25    8834.870117
# 2020-02-26    8873.759766
# 2020-02-27    8436.669922
# 2020-02-28    8461.830078
# Name: Close, dtype: float64

# %% [markdown]
# ## Rolling Statistics

# %%
#Plot the returns with their respective rolling mean and rolling standard deviation.
#Visually test for stationarity.

rolmean = ts_ndx_close_ma.rolling(window = 8).mean()
rolstd = ts_ndx_close_ma.rolling(window = 8).std()
fig = plt.figure(figsize=(11,5))
plt.plot(ts_ndx_close_ma, color='blue',label='Original')
plt.plot(rolmean, color='red', label='Rolling Mean')
plt.plot(rolstd, color='black', label = 'Rolling Std')
plt.legend(loc='best')
plt.title(f'Rolling Mean & Standard Deviation for Ma: 5')
plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
# Define the date format
date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
# Ensure a major tick for each 4 weeks
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))
plt.show()

# %% [markdown]
# ### Validate Stationarity

# %%
# Check for stationarity, important for forecasting
validate_stationarity(ts_ndx_close_ma)
# Out:
# ADFuller test p-value for ma: 2
# p-value: 0.8770835212641103
# p-value: (-0.5724636192673357, 0.8770835212641103, 5, 78, {'1%': -3.517113604831504, '5%': -2.8993754262546574, '10%': -2.5869547797501644}, 955.303272689406)
# Fail to reject the null hypothesis. Data is not stationary.

# %% [markdown]
# ### Remove Trends

# %% [markdown]
# #### Difference

# %%
ts_diff_ndx_close_ma = ts_ndx_close_ma.diff(periods = 8 ).dropna()
ts_diff_ndx_close_ma.head()
ts_diff_ndx_close_ma.plot(figsize = (12,8))

plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
# Define the date format
date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
# Ensure a major tick for each 4 weeks
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))

# %%
#Take a look at rolling mean and rolling std now after differencing
rolling_mean = ts_diff_ndx_close_ma.rolling(window = 5).mean()
rolling_std = ts_diff_ndx_close_ma.rolling(window = 5).std()

plt.plot(rolling_mean, color = 'red')
plt.plot(rolling_std, color = 'blue')

plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
# Define the date format
date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
# Ensure a major tick for each 4 weeks
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))

# %% [markdown]
# #### Subtract Weighted Rolling Mean

# %%
# # Use Pandas ewm() to calculate Exponential Weighted Moving Average
exp_roll_mean = ts_ndx_close_ma.ewm(halflife=2).mean()

# %%
# Plot the original data with exp weighted average
fig = plt.figure(figsize=(12,7))
orig = plt.plot(ts_ndx_close_ma, color='blue',label='Original')
mean = plt.plot(exp_roll_mean, color='red', label='Exponentially Weighted Rolling Mean')
plt.legend(loc='best')
plt.title('Exponentially Weighted Rolling Mean & Standard Deviation')

plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
# Define the date format
date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
# Ensure a major tick for each 4 weeks
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))

plt.show(block=False)

# %%
# Subtract the moving average from the original data
ts_ndx_close_ma_minus_exp_roll_mean = ts_ndx_close_ma - exp_roll_mean
ts_ndx_close_ma_minus_exp_roll_mean.head(15)
# Out:
# Date
# 2020-02-24      0.000000
# 2020-02-25   -101.382814
# 2020-02-26    -34.178647
# 2020-02-27   -287.226697
# 2020-02-28   -168.826332
# 2020-03-02    164.536013
# 2020-03-03    -80.735222
# 2020-03-04    188.434766
# 2020-03-05    -61.855758
# 2020-03-09   -548.001163
# 2020-03-10    -86.693443
# 2020-03-11   -318.102944
# 2020-03-12   -746.468069
# 2020-03-13    -10.472071
# 2020-03-16   -695.145871
# Name: Close, dtype: float64

# %%
fig = plt.figure(figsize=(11,7))
plt.plot(ts_ndx_close_ma_minus_exp_roll_mean, color='blue',label='ma8 - rolling mean')
plt.legend(loc='best')
plt.title('ma8 while the rolling mean is subtracted')

plt.xticks(
        rotation=45, 
        horizontalalignment='right',
        fontsize='x-small')
# Define the date format
date_form = DateFormatter("%Y-%m-%d")
ax.xaxis.set_major_formatter(date_form)
# Ensure a major tick for each 4 weeks
ax.xaxis.set_major_locator(mdates.WeekdayLocator(interval=4))
plt.show(block=False)

# %% [markdown]
# #### Validate Stationarity

# %%
# Validate Stationarity with Dickey Fuller test after differencing
validate_stationarity(ts_diff_ndx_close_ma)
# Out:
# ADFuller test p-value for ma: 2
# p-value: 0.0005819958925919904
# p-value: (-4.23172479241368, 0.0005819958925919904, 8, 67, {'1%': -3.5319549603840894, '5%': -2.905755128523123, '10%': -2.5903569458676765}, 860.9096200063881)
# Reject the null hypothesis. Data is stationary.

# %%
# Validate Stationarity with Dickey Fuller test after differencing
validate_stationarity(ts_ndx_close_ma_minus_exp_roll_mean)
# Out:
# ADFuller test p-value for ma: 2
# p-value: 0.14372711478743672
# p-value: (-2.392981571392874, 0.14372711478743672, 4, 79, {'1%': -3.5159766913976376, '5%': -2.898885703483903, '10%': -2.5866935058484217}, 905.0099107548162)
# Fail to reject the null hypothesis. Data is not stationary.

# %% [markdown]
# - Use ARIMA model as data is stationary = ARMA + preliminary differencing procedure above ts_diff_ndx_close_ma

# %% [markdown]
# - Analysis:
#      After attempting to remove trends through differencing, subtracting the weighted rolling mean the
#      data IS stationary.  Use ARIMA model.

# %% [markdown]
# #### Seasonal Decomposition

# %%
#Data is stationary, there are no trends so continue to ARIMA model

# %% [markdown]
# #### ACF/PACF

# %%
acf_pacf(ts_diff_ndx_close_ma)

# %% [markdown]
# Behaviour of the ACF and PACF for ARMA Models
#
# ACF
# -	Tails off at AR(p)
# -	Cuts off after lag q MA(q)
# -	Tails off ARMA (p,q)
#
# PACF
# -	Cuts off after lag p AR(p)
# -	Tails off MA(q)
# -	Tails off ARMA (p,q)

# %% [markdown]
# #### PDQ/S Parameters

# %%
AIC_PDQS(ts_diff_ndx_close_ma)
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =1174.1623608359532
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =939.3528695150267
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =1010.9934406257777
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =756.9608589947757
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =967.5006647876721
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =940.3766361705204
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =770.9237319924403
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =752.6502401541974
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =1129.8652146919612
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =902.6199344027596
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =973.6506034345742
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =724.8505889768688
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =949.9560126059905
# ...

# %% [markdown]
# - Auto-Regressive (p) -> Number of autoregressive terms.
#
# - Integrated (d) -> Number of nonseasonal differences needed for stationarity.
#
# - Moving Average (q) -> Number of lagged forecast errors in the prediction equation.

# %% [markdown]
# #### ARMA Model

# %%
#Setup train test split with dates for testing

# %%
#     train, test = train_test(df)
train, test, train_before_covid19, test_before_covid19, train_during_covid19, test_during_covid19, train_before_and_during_covid19, test_before_and_during_covid19, train_first_month_covid19, test_first_month_covid19 = train_test(ts_diff_ndx_close_ma)

# %% [markdown]
# #### Train Test Split

# %% [markdown]
# ##### BEFORE Covid19

# %%
# #     #Set training data before Covid19 
# #     train_before_covid19 = df['2019-07':'2019-11']
# #     #Set test data starting Covid19
# #     test_before_covid19 = df['2019-12':'2020-02']
# for ma_lag in range(1, 10): 

#      print(f'Train Test Split DURING Covid19 - MA lag: {ma_lag}')
#      ts_diff_ndx_close_ma = ts_ndx_close_ma.diff(periods = ma_lag ).dropna()
#      train_before_covid19, test_before_covid19, 
#      results = model_fit(ts_diff_ndx_close_ma,train_before_covid19, test_before_covid19, order=(0,1))

# %% [markdown]
# ##### FIRST MONTH Covid19

# %%
#     Set training data first month Covid19 announced
#     train_first_month_covid19 = df['2020-02':'2020-03']
#     Set test data
#     test_first_month_covid19 = df['2020-04':'2020-05']

for ma_lag in range(1, 10): 

    print(f'Train Test Split DURING Covid19 - MA lag: {ma_lag}')
    ts_diff_ndx_close_ma = ts_ndx_close_ma.diff(periods = ma_lag ).dropna()
    train_first_month_covid19, test_first_month_covid19, 
    results = model_fit(ts_diff_ndx_close_ma,train_first_month_covid19, test_first_month_covid19, order=(0,1))
# Out:
# Train Test Split DURING Covid19 - MA lag: 1
# ---------------------RESULTS OUTPUT---------------------
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                   61
# Model:                     ARMA(1, 1)   Log Likelihood                -428.625
# Method:                       css-mle   S.D. of innovations            271.961
# Date:                Tue, 29 Dec 2020   AIC                            865.250
# Time:                        15:15:22   BIC                            873.694
# Sample:                             0   HQIC                           868.559
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0329     23.645      0.297      0.767     -39.310      53.375
# ar.L1.y       -0.4570      0.183     -2.493      0.016      -0.816      -0.098
# ...

# %% [markdown]
# ##### DURING Covid19

# %%
#     Set training data starting into first 5 months of Covid19
#     train_during_covid19 = df['2020-03':'2020-05']
#     Set test data end of Covid19 test period last month
#     test_during_covid19 = df['2020-06':]

for ma_lag in range(1, 10): 

    print(f'Train Test Split DURING Covid19 - MA lag: {ma_lag}')
    ts_diff_ndx_close_ma = ts_ndx_close_ma.diff(periods = ma_lag ).dropna()
    train_during_covid19, test_during_covid19, 
    results = model_fit(ts_diff_ndx_close_ma,train_during_covid19, test_during_covid19, order=(0,1))
# Out:
# Train Test Split DURING Covid19 - MA lag: 1
# ---------------------RESULTS OUTPUT---------------------
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                   78
# Model:                     ARMA(1, 1)   Log Likelihood                -540.128
# Method:                       css-mle   S.D. of innovations            245.698
# Date:                Tue, 29 Dec 2020   AIC                           1088.255
# Time:                        13:53:47   BIC                           1097.682
# Sample:                             0   HQIC                          1092.029
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.2521     18.884      0.914      0.364     -19.760      54.265
# ar.L1.y       -0.4783      0.166     -2.874      0.005      -0.804      -0.152
# ...

# %% [markdown]
# ##### BEFORE AND DURING Covid19

# %%
#     Set training data starting into first 5 months of Covid19
#     train_before_and_during_covid19 = df[:'2020-05']
#     Set test data end of Covid19 test period last month
#     test_before_and_during_covid19 = df['2020-06':]

for ma_lag in range(1, 10): 

    print(f'Train Test Split BEFORE AND DURING Covid19 - MA lag: {ma_lag}')
    ts_diff_ndx_close_ma = ts_ndx_close_ma.diff(periods = ma_lag ).dropna()
    train_before_and_during_covid19, test_before_and_during_covid19, 
    results = model_fit(ts_diff_ndx_close_ma,train_before_and_during_covid19, test_before_and_during_covid19, order=(1,1))
    #pred = forecast_model(ts_diff_ndx_close_ma,order=(1,1))
# Out:
# Train Test Split BEFORE AND DURING Covid19 - MA lag: 1
# ---------------------RESULTS OUTPUT---------------------
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                   82
# Model:                     ARMA(1, 1)   Log Likelihood                -568.579
# Method:                       css-mle   S.D. of innovations            248.028
# Date:                Tue, 29 Dec 2020   AIC                           1145.157
# Time:                        13:55:01   BIC                           1154.784
# Sample:                             0   HQIC                          1149.022
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3901     18.805      0.606      0.546     -25.468      48.248
# ar.L1.y       -0.4435      0.170     -2.605      0.011      -0.777      -0.110
# ...

# %% [markdown]
# ##### Analysis of Results

# %% [markdown]
# ###### FIRST MONTH of Covid19

# %%
#                              ARMA Model Results                              
#==============================================================================
#Dep. Variable:                      y   No. Observations:                   61
#Model:                     ARMA(1, 1)   Log Likelihood                -428.625
#Method:                       css-mle   S.D. of innovations            271.961
#Date:                Tue, 29 Dec 2020   AIC                            865.250
#Time:                        15:15:54   BIC                            873.694
#Sample:                             0   HQIC                           868.559
                                                                              
#==============================================================================
#                 coef    std err          z      P>|z|      [0.025      0.975]
#------------------------------------------------------------------------------
#const          7.0329     23.645      0.297      0.767     -39.310      53.375
#ar.L1.y       -0.4570      0.183     -2.493      0.016      -0.816      -0.098
#ma.L1.y       -0.0161      0.186     -0.087      0.931      -0.380       0.348
#                                    Roots                                    
#=============================================================================
#                  Real          Imaginary           Modulus         Frequency
#-----------------------------------------------------------------------------
#AR.1           -2.1882           +0.0000j            2.1882            0.5000
#MA.1           62.0425           +0.0000j           62.0425            0.0000
#-----------------------------------------------------------------------------
#predicted=22.009184, expected=138.809570

# %% [markdown]
# ###### DURING Covid19

# %%
#                              ARMA Model Results                              
#==============================================================================
#Dep. Variable:                      y   No. Observations:                   78
#Model:                     ARMA(1, 1)   Log Likelihood                -540.128
#Method:                       css-mle   S.D. of innovations            245.698
#Date:                Tue, 29 Dec 2020   AIC                           1088.255
#Time:                        13:54:23   BIC                           1097.682
#Sample:                             0   HQIC                          1092.029
#                                                                              
#==============================================================================
#                 coef    std err          z      P>|z|      [0.025      0.975]
#------------------------------------------------------------------------------
#const         17.2521     18.884      0.914      0.364     -19.760      54.265
#ar.L1.y       -0.4783      0.166     -2.874      0.005      -0.804      -0.152
#ma.L1.y       -0.0007      0.171     -0.004      0.997      -0.336       0.334

#predicted=146.411915, expected=111.799805

# %% [markdown]
# ###### BEFORE AND DURING Covid19

# %%
#Train Test Split BEFORE AND DURING Covid19 - MA lag: 9
#---------------------RESULTS OUTPUT---------------------
#                              ARMA Model Results                              
#==============================================================================
#Dep. Variable:                      y   No. Observations:                   82
#Model:                     ARMA(1, 1)   Log Likelihood                -568.579
#Method:                       css-mle   S.D. of innovations            248.028
#Date:                Tue, 29 Dec 2020   AIC                           1145.157
#Time:                        13:55:33   BIC                           1154.784
#Sample:                             0   HQIC                          1149.022
                                                                              
#==============================================================================
#                 coef    std err          z      P>|z|      [0.025      0.975]
#------------------------------------------------------------------------------
#const         11.3901     18.805      0.606      0.546     -25.468      48.248
#ar.L1.y       -0.4435      0.170     -2.605      0.011      -0.777      -0.110
#ma.L1.y       -0.0130      0.174     -0.075      0.940      -0.354       0.328
#                                    Roots                                    
#=============================================================================
#                  Real          Imaginary           Modulus         Frequency
#-----------------------------------------------------------------------------
#AR.1           -2.2548           +0.0000j            2.2548            0.5000
#MA.1           76.6562           +0.0000j           76.6562            0.0000
#-----------------------------------------------------------------------------
#predicted=131.334477, expected=111.799805

# %% [markdown]
# The model returns a lot of information, but we'll focus only on the table of coefficients. The coefficient columns above show the importance of each feature and how each one impacts the time series patterns. The $P>|z|$ provides the significance of each feature weight.
#
# For our timeseries, we see that each weight for ar.L1.y has a p-value lower or close to 0.05, so it is reasonable to retain all of them in our model.

# %% [markdown]
# The purpose of modeling with residuals is so that we get them closer to remaining uncorrelated, normally distributed having zero mean. In the absence of these assumptions, we can not move forward and need further tweaking of the model.  As the data is numerically sensitive with significant outliers given the period of the market crash, the residuals remaining are too reflective of this volatility.
#
# These observations lead us to conclude that our model has correlations and does not provide a satisfactory fit to help forecast future values.

# %% [markdown]
# # Final Analysis

# %% [markdown]
# There were no seasonal trends and no radical shifts, further clarified as 'non-random' by a strong P value that
# would allow us to confirm that the Nasdaq index price traded faster/slower on the daily ma during the Covid19
# period.
#
# - The co-efficient values on the train test split DURING and in the FIRST MONTH of Covid19 showed a STRONGER predictive value
# than the period that included both BEFORE AND DURING Covid19.  The shorter the period modelled of
# Covid19, the easier it was to predict the close price.
#
# - The lower PValue of 0.005 in the DURING Covid19 showed that there was a more likely
# reason for the close price change rather than by random chance.  There was no pattern of change in speed of
# price change.
#
#
# - The co-efficient values on the train test split did not show any difference between the ma daily lags
# from 1 - 10 Hence the stock market NASDAQ index did not trade significantly faster/slower on the 'Daily'
# Close Price Nasdaq Close Price DURING Covid19 and BEFORE AND DURING Covid19. I would recommend the possibility to look at the data of faster moving averages like the 5min / 10 min / 15 min / 30 min / 1 hr / 4hrs, this however would require a substantial amount of data to model over the period of 1 year.

# %% [markdown]
# # Recommendations

# %% [markdown]
# This analysis may be adjusted to analyse data of a number of permutations of risk for the Nasdaq ma:
# - The results were based on the ma data of the Daily Nasdaq Close Price.  Analysis may be further detailed by extracting faster or slower moving averages from 2 minutes, and for a long term perspective to monthly.  The extraction of faster ma data would be more insightful during the short term period of the initial stock market covid19 crash.
#
# This analysis may be adjusted to analyse data of a number of permutations of risk for Covid19 ma:
# - Including world wide case numbers or other news tangents including number of positive vaccine announcements or consistent feeds related to Covid19.
#
#
# - Analysis of the seasonal patterns according to the rolling mean showed that for this period of ma there were no trends.
#
#
#
# - The rolling mean period can be extended to n days, n months, n years, depending on the amount of data being analysed versus prediction power, in order to further remove any trends and increase stationarity of data.
